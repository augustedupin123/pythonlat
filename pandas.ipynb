# %%
import pandas as pd

# %%
data = pd.read_csv('Test.csv')

# %%
data.shape
# Out:
# (5681, 11)

# %%
data.head(3)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58        20.75          Low Fat         0.007565  Snack Foods
# 1           FDW14         8.30              reg         0.038428        Dairy
# 2           NCN55        14.60          Low Fat         0.099575       Others
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
#
#   Outlet_Location_Type        Outlet_Type
# 0               Tier 1  Supermarket Type1
# 1               Tier 2  Supermarket Type1
# 2               Tier 3      Grocery Store

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# dtype: object

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5681, step=1)

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
data.head(7)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDW58       20.750          Low Fat         0.007565
# 1           FDW14        8.300              reg         0.038428
# 2           NCN55       14.600          Low Fat         0.099575
# 3           FDQ58        7.315          Low Fat         0.015388
# 4           FDY38          NaN          Regular         0.118599
# 5           FDH56        9.800          Regular         0.063817
# 6           FDL48       19.350          Regular         0.082602
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# 1                  Dairy   87.3198            OUT017
# 2                 Others  241.7538            OUT010
# 3            Snack Foods  155.0340            OUT017
# 4                  Dairy  234.2300            OUT027
# 5  Fruits and Vegetables  117.1492            OUT046
# 6           Baking Goods   50.1034            OUT018
#
# ...

# %%
#changing index of a dataframe
import random

# %%
random_list = [random.randint(1,5681) for i in range(5681)]

# %%
random_list
# Out:
# [686,
#  1399,
#  1053,
#  4209,
#  5077,
#  4698,
#  4579,
#  1361,
#  1955,
#  3451,
#  4576,
#  4393,
#  4582,
#  5575,
#  5301,
#  5629,
#  655,
#  5022,
#  2280,
#  3331,
#  2548,
#  5280,
#  220,
#  2808,
#  2383,
#  4932,
#  34,
#  2905,
#  3523,
#  4090,
#  4888,
#  2891,
#  4820,
#  311,
#  2418,
#  5023,
#  2717,
#  343,
#  3243,
#  221,
#  4084,
#  382,
#  2024,
#  2278,
#  2858,
#  1174,
#  2587,
#  3788,
#  925,
#  5459,
#  1531,
#  5514,
#  2424,
#  3794,
#  2818,
#  147,
#  351,
#  4576,
#  141,
#  5233,
#  3493,
#  526,
#  184,
#  3161,
#  921,
#  5637,
#  824,
#  5394,
#  1094,
#  1744,
#  1370,
#  357,
#  2794,
#  2372,
#  32,
#  751,
#  2702,
#  5076,
#  3789,
#  2065,
#  1221,
#  5317,
#  2137,
#  2007,
#  3764,
#  329,
#  5388,
#  2003,
#  978,
#  3996,
#  775,
#  1373,
#  4738,
#  630,
#  1070,
#  1296,
#  951,
#  1064,
#  2587,
#  4605,
#  2499,
#  3086,
#  5096,
#  449,
#  3787,
#  2067,
#  4396,
#  1281,
#  4995,
#  3642,
#  5394,
#  4501,
#  5474,
#  3330,
# ...

# %%
data.index = random_list

# %%
data.head(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 686            FDW58       20.750          Low Fat         0.007565
# 1399           FDW14        8.300              reg         0.038428
# 1053           NCN55       14.600          Low Fat         0.099575
# 4209           FDQ58        7.315          Low Fat         0.015388
# 5077           FDY38          NaN          Regular         0.118599
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 686   Snack Foods  107.8622            OUT049                       1999
# 1399        Dairy   87.3198            OUT017                       2007
# 1053       Others  241.7538            OUT010                       1998
# 4209  Snack Foods  155.0340            OUT017                       2007
# 5077        Dairy  234.2300            OUT027                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type
# 686       Medium               Tier 1  Supermarket Type1
# ...

# %%
data.set_index('Outlet_Establishment_Year', drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 data.set_index('Outlet_Establishment_Year', drop=True, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
# ...

# %%
data_updated.index
# Out:
# Int64Index([1999, 2007, 1998, 2007, 1985, 1997, 2009, 1985, 2002, 2007,
#             ...
#             1999, 1999, 2009, 1997, 1999, 1997, 2009, 2002, 2007, 2002],
#            dtype='int64', name='Outlet_Establishment_Year', length=5681)

# %%
#above the indexing was changed, now every row indexed by year

# %%
data.head()
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDW58       20.750          Low Fat
# 2007                                FDW14        8.300              reg
# 1998                                NCN55       14.600          Low Fat
# 2007                                FDQ58        7.315          Low Fat
# 1985                                FDY38          NaN          Regular
#
#                            Item_Visibility    Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.007565  Snack Foods  107.8622
# 2007                              0.038428        Dairy   87.3198
# 1998                              0.099575       Others  241.7538
# 2007                              0.015388  Snack Foods  155.0340
# 1985                              0.118599        Dairy  234.2300
#
#                           Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# ...

# %%
data.set_index('Item_Identifier', drop=True, inplace=True)

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# Item_Identifier
# FDW58                 20.750          Low Fat         0.007565  Snack Foods
# FDW14                  8.300              reg         0.038428        Dairy
# NCN55                 14.600          Low Fat         0.099575       Others
# FDQ58                  7.315          Low Fat         0.015388  Snack Foods
# FDY38                    NaN          Regular         0.118599        Dairy
#
#                  Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# FDW58            107.8622            OUT049      Medium               Tier 1
# FDW14             87.3198            OUT017         NaN               Tier 2
# NCN55            241.7538            OUT010         NaN               Tier 3
# FDQ58            155.0340            OUT017         NaN               Tier 2
# FDY38            234.2300            OUT027      Medium               Tier 3
#
# ...

# %%
data.index
# Out:
# Index(['FDW58', 'FDW14', 'NCN55', 'FDQ58', 'FDY38', 'FDH56', 'FDL48', 'FDC48',
#        'FDN33', 'FDA36',
#        ...
#        'FDA01', 'NCH42', 'FDF46', 'DRL35', 'FDW46', 'FDB58', 'FDD47', 'NCO17',
#        'FDJ26', 'FDU37'],
#       dtype='object', name='Item_Identifier', length=5681)

# %%
#Subsetting the data using loc:

# %%
data.loc['FDA15']
# Out:
# Item_Weight                           9.3
# Item_Fat_Content                  Low Fat
# Item_Visibility                  0.016022
# Item_Type                           Dairy
# Item_MRP                         249.9092
# Outlet_Identifier                  OUT046
# Outlet_Size                         Small
# Outlet_Location_Type               Tier 1
# Outlet_Type             Supermarket Type1
# Name: FDA15, dtype: object

# %%
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# 0  107.8622            OUT049      Medium               Tier 1
# 1   87.3198            OUT017         NaN               Tier 2
# 2  241.7538            OUT010         NaN               Tier 3
# 3  155.0340            OUT017         NaN               Tier 2
# 4  234.2300            OUT027      Medium               Tier 3
#
#          Outlet_Type
# 0  Supermarket Type1
# 1  Supermarket Type1
# 2      Grocery Store
# 3  Supermarket Type1
# ...

# %%
data[data['Item_Type'] == 'Dairy']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 1              FDW14        8.300              reg         0.038428     Dairy
# 4              FDY38          NaN          Regular         0.118599     Dairy
# 28             DRC27       13.800          Low Fat         0.058102     Dairy
# 46             FDR14       11.650          Low Fat         0.291322     Dairy
# 59             FDE52       10.395          Regular         0.029947     Dairy
# ...              ...          ...              ...              ...       ...
# 5620           FDB15       10.895          Low Fat         0.137088     Dairy
# 5631           FDA03       18.500          Regular         0.045556     Dairy
# 5649           DRH03       17.250          Low Fat         0.035135     Dairy
# 5656           FDC39          NaN          Low Fat         0.158425     Dairy
# 5665           DRE03          NaN          Low Fat         0.024110     Dairy
#
# ...

# %%
data[10:20]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 10           FDT44       16.600          Low Fat         0.103569
# 11           FDQ56        6.590          Low Fat         0.105811
# 12           NCC54          NaN          Low Fat         0.171079
# 13           FDU11        4.785          Low Fat         0.092738
# 14           DRL59       16.750               LF         0.021206
# 15           FDM24        6.135          Regular         0.079451
# 16           FDI57       19.850          Low Fat         0.054135
# 17           DRC12       17.850          Low Fat         0.037981
# 18           NCM42          NaN          Low Fat         0.028184
# 19           FDA46       13.600          Low Fat         0.196898
#
#                 Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 10  Fruits and Vegetables  118.3466            OUT017         NaN
# 11  Fruits and Vegetables   85.3908            OUT045         NaN
# ...

# %%
data[-10:]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5671           FDA01        15.00              reg         0.054463
# 5672           NCH42         6.86          Low Fat         0.036594
# 5673           FDF46         7.07          Low Fat         0.094053
# 5674           DRL35        15.70          Low Fat         0.030704
# 5675           FDW46        13.00          Regular         0.070411
# 5676           FDB58        10.50          Regular         0.013496
# 5677           FDD47         7.60          Regular         0.142991
# 5678           NCO17        10.00          Low Fat         0.073529
# 5679           FDJ26        15.30          Regular         0.000000
# 5680           FDU37         9.50          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 5671              Canned   59.5904            OUT049      Medium
# 5672           Household  231.1010            OUT049      Medium
# ...

# %%
#iloc - select specific rows by index no.

# %%
#select specific rows
data.iloc[[1,6,2,4,8,16]]
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1            FDW14        8.300              reg         0.038428
# 6            FDL48       19.350          Regular         0.082602
# 2            NCN55       14.600          Low Fat         0.099575
# 4            FDY38          NaN          Regular         0.118599
# 8            FDN33        6.305          Regular         0.123365
# 16           FDI57       19.850          Low Fat         0.054135
#
#        Item_Type  Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# 1          Dairy   87.3198            OUT017         NaN               Tier 2
# 6   Baking Goods   50.1034            OUT018      Medium               Tier 3
# 2         Others  241.7538            OUT010         NaN               Tier 3
# 4          Dairy  234.2300            OUT027      Medium               Tier 3
# 8    Snack Foods   95.7436            OUT045         NaN               Tier 2
# ...

# %%
#select specific rows and columns
data.iloc[[1,4,5,2],[1,3,5]]
# Out:
#    Item_Weight  Item_Visibility  Item_MRP
# 1          8.3         0.038428   87.3198
# 4          NaN         0.118599  234.2300
# 5          9.8         0.063817  117.1492
# 2         14.6         0.099575  241.7538

# %%
data.set_index('Item_Identifier', inplace=True, drop=True)

# %%
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# Item_Identifier
# FDW58                 20.750          Low Fat         0.007565  Snack Foods
# FDW14                  8.300              reg         0.038428        Dairy
# NCN55                 14.600          Low Fat         0.099575       Others
# FDQ58                  7.315          Low Fat         0.015388  Snack Foods
# FDY38                    NaN          Regular         0.118599        Dairy
#
#                  Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# FDW58            107.8622            OUT049      Medium               Tier 1
# FDW14             87.3198            OUT017         NaN               Tier 2
# NCN55            241.7538            OUT010         NaN               Tier 3
# FDQ58            155.0340            OUT017         NaN               Tier 2
# FDY38            234.2300            OUT027      Medium               Tier 3
#
# ...

# %%
data.loc['FDA15']
# Out:
# Item_Weight                           9.3
# Item_Fat_Content                  Low Fat
# Item_Visibility                  0.016022
# Item_Type                           Dairy
# Item_MRP                         249.9092
# Outlet_Identifier                  OUT046
# Outlet_Size                         Small
# Outlet_Location_Type               Tier 1
# Outlet_Type             Supermarket Type1
# Name: FDA15, dtype: object

# %%
data.loc[['FDA15', 'FDA03']]
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016022     Dairy
# FDA03                   18.5          Regular         0.045649     Dairy
# FDA03                   18.5          Regular         0.045721     Dairy
# FDA03                   18.5          Regular         0.045556     Dairy
#
#                  Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# FDA15            249.9092            OUT046       Small               Tier 1
# FDA03            145.6102            OUT018      Medium               Tier 3
# FDA03            145.6102            OUT017         NaN               Tier 2
# FDA03            147.1102            OUT045         NaN               Tier 2
#
#                        Outlet_Type
# Item_Identifier
# FDA15            Supermarket Type1
# FDA03            Supermarket Type2
# FDA03            Supermarket Type1
# ...

# %%
data.loc[['FDA15', 'FDA03'],'Item_Fat_Content']
# Out:
# Item_Identifier
# FDA15    Low Fat
# FDA03    Regular
# FDA03    Regular
# FDA03    Regular
# Name: Item_Fat_Content, dtype: object

# %%
data.loc[['FDA15', 'FDA03'],'Item_Fat_Content']
# Out:
# Item_Identifier
# FDA15    Low Fat
# FDA03    Regular
# FDA03    Regular
# FDA03    Regular
# Name: Item_Fat_Content, dtype: object
